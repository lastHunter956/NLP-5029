# %% [markdown]
# # Word tokenization

# %% [markdown]
# ## PATH

# %%
import os
import sys
PATH = os.getcwd()
DIR_DATA = PATH + '{0}courseNLP{0}examples{0}data{0}matilda{0}'.format(os.sep)
sys.path.append(PATH) if PATH not in list(sys.path) else None
DIR_DATA
# Out:
# '/Volumes/ADATA SD620/Programacion 7.0/actividades nlp/laboratorio 1/courseNLP/example/data/matilda/'

# %% [markdown]
# ## Python Libraries

# %%
import pandas as pd
import glob
import nltk
from nltk.tokenize import word_tokenize
import spacy

# %%
# Descargar recursos necesarios de NLTK (solo la primera vez)
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jesusmartinez/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !python -m spacy download es_core_news_sm
# Out:
# Collecting es-core-news-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
# Cargar modelo en español (puedes cambiarlo por 'en_core_web_sm' para inglés)
nlp = spacy.load("es_core_news_sm")

# %%
ruta_archivos = DIR_DATA +  "*.txt"
print(f"Ruta de archivos: {ruta_archivos}")
# Out:
# Ruta de archivos: /Volumes/ADATA SD620/Programacion 7.0/actividades nlp/laboratorio 1/courseNLP/example/data/matilda/*.txt

# %%
# Obtener lista de archivos
archivos = glob.glob(ruta_archivos)
print(f"Archivos encontrados: {archivos}")
# Out:
# Archivos encontrados: []

# %%
# Leer y concatenar el contenido de todos los archivos en un solo string
texto_unido = ""

for archivo in archivos:
    with open(archivo, "r", encoding="utf-8") as file:
        print(f"Procesando archivo: {archivo}")
        texto_unido += file.read() + "\n"  # Agregar un salto de línea entre archivos

# %%
texto_unido[:1000]
# Out:
# ''

# %% [markdown]
# ## Tokenición con NLTK

# %%
import nltk

# Descargamos los dos paquetes esenciales para tokenizar
nltk.download('punkt')
nltk.download('punkt_tab') # En versiones recientes de NLTK es necesario
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jesusmartinez/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/jesusmartinez/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Tokenizar el texto
tokens = word_tokenize(texto_unido)

tokens[:50]  # Mostrar los primeros 50 tokens
# Out:
# []

# %% [markdown]
# ## Tokenización con spaCy

# %%
chunk_size = 500000  # Dividir en fragmentos de 500,000 caracteres
chunks = [texto_unido[i:i+chunk_size] for i in range(0, len(texto_unido), chunk_size)]

tokens_totales = []

# Procesar cada fragmento por separado
for chunk in chunks:
    doc = nlp(chunk)
    tokens_totales.extend([token.text for token in doc])

print(tokens_totales[:50])  # Mostrar los primeros 50 tokens
# Out:
# []

# %%
for chunk in chunks:
    doc = nlp(chunk)
    print([token for token in doc])
